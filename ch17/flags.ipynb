# %%
# %pip install requests

# %%
# %load_ext pycodestyle_magic
# %pycodestyle_on

# %%
import doctest

# %%
import os
import pathlib
import requests
import shutil
import tempfile
import time

SERVER_URL = 'http://localhost:8001'

URL_FMT = SERVER_URL + '/flags/{cc}/{cc}.gif'

DEST_DIR = 'downloads/'
if os.path.exists(DEST_DIR):
    shutil.rmtree(DEST_DIR)
    os.mkdir(DEST_DIR)
else:
    os.mkdir(DEST_DIR)


ALL_CC = (
    'AD AM AZ BF BN BW CF CM CV DK EG FJ GD GQ HN IE IS KE KN LA LR LY '
    'MG MN MW NE NP PE PT RS SC SK SR SZ TL TT UG VC YE AE AO BA BG BO '
    'BY CG CN CY DM ER FM GE GR HR IL IT KG KP LB LS MA MH MR MX NG NR '
    'PG PW RU SD SL SS TD TM TV US VE ZA AF AR BB BH BR BZ CH CO CZ DZ '
    'ES FR GH GT HT IN JM KH KR LC LT MC MK MT MY NI NZ PH PY RW SE SM '
    'ST TG TN TW UY VN ZM AG AT BD BI BS CA CI CR DE EC ET GA GM GW HU '
    'IQ JO KI KW LI LU MD ML MU MZ NL OM PK QA SA SG SN SV TH TO TZ UZ '
    'VU ZW AL AU BE BJ BT CD CL CU DJ EE FI GB GN GY ID IR JP KM KZ LK '
    'LV ME MM MV NA NO PA PL RO SB SI SO SY TJ TR UA VA WS'.split()
)

POP20_CC = ('CN IN US ID BR PK NG BD RU JP '
            'MX PH VN ET EG DE IR TR CD FR'.split())


def save_flag(img, filename):
    path = os.path.join(DEST_DIR, filename)
    with open(path, 'wb') as fp:
        fp.write(img)


def get_flag(cc):
    url = URL_FMT.format(cc=cc.lower())
    resp = requests.get(url)
    return resp.content


def show(text):
    print(text, end=' ')
    # sys.stdout.flush()


def main(download_many):
    t0 = time.perf_counter()
    count = download_many(ALL_CC)
    elapsed = time.perf_counter() - t0
    print()
    print(f'donwloaded {count} flags in {elapsed:.4f}s')

# %%
def download_many(cc_list):
    for cc in sorted(cc_list):
        image = get_flag(cc)
        show(cc)
        save_flag(image, f'{cc.lower()}.gif')

    return len(cc_list)


main(download_many)
# Out:
# AD AE AF AG AL AM AO AR AT AU AZ BA BB BD BE BF BG BH BI BJ BN BO BR BS BT BW BY BZ CA CD CF CG CH CI CL CM CN CO CR CU CV CY CZ DE DJ DK DM DZ EC EE EG ER ES ET FI FJ FM FR GA GB GD GE GH GM GN GQ GR GT GW GY HN HR HT HU ID IE IL IN IQ IR IS IT JM JO JP KE KG KH KI KM KN KP KR KW KZ LA LB LC LI LK LR LS LT LU LV LY MA MC MD ME MG MH MK ML MM MN MR MT MU MV MW MX MY MZ NA NE NG NI NL NO NP NR NZ OM PA PE PG PH PK PL PT PW PY QA RO RS RU RW SA SB SC SD SE SG SI SK SL SM SN SO SR SS ST SV SY SZ TD TG TH TJ TL TM TN TO TR TT TV TW TZ UA UG US UY UZ VA VC VE VN VU WS YE ZA ZM ZW
# donwloaded 194 flags in 1.6000s

# %%
from concurrent import futures
from timeit import timeit

MAX_WORKERS = 20


def download_one(cc):
    image = get_flag(cc)
    show(cc)
    save_flag(image, cc.lower() + '.gif')
    return cc


def download_many(cc_list):
    num_workers = min(MAX_WORKERS, len(cc_list))
    with futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
        # results = executor.map(download_one, sorted(cc_list))
        todo = []
        for cc in sorted(cc_list):
            future = executor.submit(download_one, cc)
            todo.append(future)
            print(f'scheduled for {cc}: {future}')

        results = []
        for future in futures.as_completed(todo):
            res = future.result()
            print(f'{future} result: {res!r}')
            results.append(res)

    return len(list(results))


main(download_many)
# Out:
# scheduled for AD: <Future at 0x7fcc580b7460 state=running>
# scheduled for AE: <Future at 0x7fcc49c7eaf0 state=running>
# scheduled for AF: <Future at 0x7fcc49ed8a90 state=running>
# scheduled for AG: <Future at 0x7fcc49ee7ee0 state=running>
# AD AF scheduled for AL: <Future at 0x7fcc49eeb040 state=running>
# scheduled for AM: <Future at 0x7fcc49cb84f0 state=running>
# AE AG scheduled for AO: <Future at 0x7fcc49ed8040 state=running>
# scheduled for AR: <Future at 0x7fcc49eeb190 state=pending>
# scheduled for AT: <Future at 0x7fcc49c533d0 state=pending>AL
# AO scheduled for AU: <Future at 0x7fcc49c7ec10 state=pending>AM
# scheduled for AZ: <Future at 0x7fcc49c7ebe0 state=running>ATAR
# scheduled for BA: <Future at 0x7fcc580f34f0 state=pending>
# scheduled for BB: <Future at 0x7fcc49cb8610 state=pending>
# AZ scheduled for BD: <Future at 0x7fcc49cbaf40 state=running>
# scheduled for BE: <Future at 0x7fcc49c5d9a0 state=pending>
# scheduled for BF: <Future at 0x7fcc49c5d7c0 state=pending>
# AUscheduled for BG: <Future at 0x7fcc49c5d820 state=running>
# BD scheduled for BH: <Future at 0x7fcc49ed8520 state=pending>
# scheduled for BI: <Future at 0x7fcc49c53c70 state=pending>
# scheduled for BJ: <Future at 0x7fcc49c631c0 state=pending>
# BFscheduled for BN: <Future at 0x7fcc49c6d970 state=running> BGBA BE  BB
# scheduled for BO: <Future at 0x7fcc49cbafa0 state=pending>
#  BH scheduled for BR: <Future at 0x7fcc49c7ed90 state=running>
# scheduled for BS: <Future at 0x7fcc49c7edc0 state=pending>
# BI scheduled for BT: <Future at 0x7fcc580b7880 state=pending>BJ
# BO scheduled for BW: <Future at 0x7fcc49c6df70 state=running>
# scheduled for BY: <Future at 0x7fcc49c7b4f0 state=pending>
# scheduled for BZ: <Future at 0x7fcc49c6d400 state=running>BS
# scheduled for CA: <Future at 0x7fcc49c5d8b0 state=pending>
# scheduled for CD: <Future at 0x7fcc49c63130 state=running>
# scheduled for CF: <Future at 0x7fcc48406a00 state=pending>
# scheduled for CG: <Future at 0x7fcc49ee7ac0 state=pending>
# scheduled for CH: <Future at 0x7fcc4840e7c0 state=running>
# scheduled for CI: <Future at 0x7fcc48415ee0 state=pending>
# BNBRBW scheduled for CL: <Future at 0x7fcc48421130 state=running>
# scheduled for CM: <Future at 0x7fcc48406d00 state=pending>
# scheduled for CN: <Future at 0x7fcc49c6dc10 state=pending>
# scheduled for CO: <Future at 0x7fcc49c7b670 state=pending> CH  BY CL BT CA
# scheduled for CR: <Future at 0x7fcc483fbaf0 state=pending>
# scheduled for CU: <Future at 0x7fcc48406310 state=pending>
# BZ  CM CF CNCG CO CI  scheduled for CV: <Future at 0x7fcc484061f0 state=running>
# scheduled for CY: <Future at 0x7fcc49ed8460 state=pending>
# scheduled for CZ: <Future at 0x7fcc49c6d040 state=pending>
# scheduled for DE: <Future at 0x7fcc49c5d310 state=pending>
# scheduled for DJ: <Future at 0x7fcc49c5d1c0 state=pending>
# scheduled for DK: <Future at 0x7fcc48406af0 state=pending>
# scheduled for DM: <Future at 0x7fcc48415580 state=pending>
# scheduled for DZ: <Future at 0x7fcc48415730 state=pending>
# scheduled for EC: <Future at 0x7fcc484150a0 state=pending>
# scheduled for EE: <Future at 0x7fcc48415070 state=pending>
# scheduled for EG: <Future at 0x7fcc48415ca0 state=pending>
# scheduled for ER: <Future at 0x7fcc48415c10 state=pending>
# scheduled for ES: <Future at 0x7fcc49c7b3d0 state=pending>
# scheduled for ET: <Future at 0x7fcc49c7b8e0 state=pending>
# scheduled for FI: <Future at 0x7fcc49c7b310 state=pending>
# scheduled for FJ: <Future at 0x7fcc49c7bd60 state=pending>
# scheduled for FM: <Future at 0x7fcc49c7b970 state=pending>
# scheduled for FR: <Future at 0x7fcc484219a0 state=pending>
# scheduled for GA: <Future at 0x7fcc48421430 state=pending>
# scheduled for GB: <Future at 0x7fcc48421ee0 state=pending>
# scheduled for GD: <Future at 0x7fcc484215b0 state=pending>
# scheduled for GE: <Future at 0x7fcc48421c70 state=pending>
# scheduled for GH: <Future at 0x7fcc48421820 state=pending>
# scheduled for GM: <Future at 0x7fcc484310d0 state=pending>
# scheduled for GN: <Future at 0x7fcc484312b0 state=pending>
# scheduled for GQ: <Future at 0x7fcc48431490 state=pending>
# scheduled for GR: <Future at 0x7fcc48431670 state=pending>
# scheduled for GT: <Future at 0x7fcc48431850 state=pending>
# CU scheduled for GW: <Future at 0x7fcc48415d00 state=pending>
# scheduled for GY: <Future at 0x7fcc4840e340 state=pending>
# scheduled for HN: <Future at 0x7fcc48415040 state=pending>CD CR DECV
# scheduled for HR: <Future at 0x7fcc48415cd0 state=pending>
# scheduled for HT: <Future at 0x7fcc49c63dc0 state=pending>
#  CYDJ scheduled for HU: <Future at 0x7fcc49c63550 state=pending>
# scheduled for ID: <Future at 0x7fcc49ee7910 state=pending>
# scheduled for IE: <Future at 0x7fcc49ee7f70 state=pending>
# scheduled for IL: <Future at 0x7fcc484157f0 state=pending>
# scheduled for IN: <Future at 0x7fcc48415df0 state=pending>
#  CZ  scheduled for IQ: <Future at 0x7fcc49ed85e0 state=pending>
# scheduled for IR: <Future at 0x7fcc4840ee80 state=pending>
# scheduled for IS: <Future at 0x7fcc4840ef70 state=pending>
# scheduled for IT: <Future at 0x7fcc4840e1f0 state=pending>
# scheduled for JM: <Future at 0x7fcc49cbad90 state=pending>
# scheduled for JO: <Future at 0x7fcc49c6d160 state=pending>
# scheduled for JP: <Future at 0x7fcc483fbc10 state=pending>
# scheduled for KE: <Future at 0x7fcc483fbee0 state=pending>
# scheduled for KG: <Future at 0x7fcc48406e80 state=pending>
# scheduled for KH: <Future at 0x7fcc48406f70 state=pending>
# scheduled for KI: <Future at 0x7fcc48406eb0 state=pending>
# scheduled for KM: <Future at 0x7fcc48435820 state=pending>
# scheduled for KN: <Future at 0x7fcc48435a60 state=pending>
# scheduled for KP: <Future at 0x7fcc48435c40 state=pending>
# scheduled for KR: <Future at 0x7fcc48435e20 state=pending>
# scheduled for KW: <Future at 0x7fcc483bd040 state=pending>
# scheduled for KZ: <Future at 0x7fcc483bd220 state=pending>
# scheduled for LA: <Future at 0x7fcc483bd400 state=pending>
# scheduled for LB: <Future at 0x7fcc483bd5e0 state=pending>
# scheduled for LC: <Future at 0x7fcc483bd7c0 state=pending>
# DKEC scheduled for LI: <Future at 0x7fcc483bd970 state=pending>ES
# scheduled for LK: <Future at 0x7fcc483fb880 state=pending>
# scheduled for LR: <Future at 0x7fcc483fbb20 state=pending>
# scheduled for LS: <Future at 0x7fcc483fb4f0 state=pending>
# scheduled for LT: <Future at 0x7fcc483fbe80 state=pending>
# scheduled for LU: <Future at 0x7fcc49c6d2e0 state=pending>
# scheduled for LV: <Future at 0x7fcc4840e280 state=pending>
# scheduled for LY: <Future at 0x7fcc4840edf0 state=pending>
# scheduled for MA: <Future at 0x7fcc49c63d90 state=pending>
# scheduled for MC: <Future at 0x7fcc49c7edf0 state=pending>
# scheduled for MD: <Future at 0x7fcc48421790 state=pending>
# scheduled for ME: <Future at 0x7fcc49c53130 state=pending>
# scheduled for MG: <Future at 0x7fcc484319a0 state=pending>
# scheduled for MH: <Future at 0x7fcc483c0be0 state=pending>
# scheduled for MK: <Future at 0x7fcc483c0dc0 state=pending>
# scheduled for ML: <Future at 0x7fcc483c0fa0 state=pending>
# scheduled for MM: <Future at 0x7fcc483c61c0 state=pending>
# scheduled for MN: <Future at 0x7fcc483c63a0 state=pending>
# scheduled for MR: <Future at 0x7fcc483c6580 state=pending>
# scheduled for MT: <Future at 0x7fcc483c6760 state=pending>
# scheduled for MU: <Future at 0x7fcc483c6940 state=pending>
# scheduled for MV: <Future at 0x7fcc483c6b20 state=pending>
# scheduled for MW: <Future at 0x7fcc483c6d00 state=pending>
# scheduled for MX: <Future at 0x7fcc483c6ee0 state=pending>
# scheduled for MY: <Future at 0x7fcc483ca100 state=pending>
# scheduled for MZ: <Future at 0x7fcc483ca2e0 state=pending>
# scheduled for NA: <Future at 0x7fcc483ca4c0 state=pending>
# scheduled for NE: <Future at 0x7fcc483ca6a0 state=pending>
# scheduled for NG: <Future at 0x7fcc483ca880 state=pending>
# scheduled for NI: <Future at 0x7fcc483caa60 state=pending>DM
#  EE DZscheduled for NL: <Future at 0x7fcc49c7ec40 state=pending>
#  ER EGscheduled for NO: <Future at 0x7fcc483ba160 state=pending>FJ FIGB   FM FR GEETGD
# scheduled for NP: <Future at 0x7fcc49ed8b20 state=pending>
#  scheduled for NR: <Future at 0x7fcc49ed8670 state=pending> GAGH
# scheduled for NZ: <Future at 0x7fcc49eeb7c0 state=pending>
# GM  scheduled for OM: <Future at 0x7fcc483ca670 state=pending>
# scheduled for PA: <Future at 0x7fcc48431f10 state=pending>
# scheduled for PE: <Future at 0x7fcc48431070 state=pending>
# scheduled for PG: <Future at 0x7fcc484063a0 state=pending>
# scheduled for PH: <Future at 0x7fcc483bdb20 state=pending>
# scheduled for PK: <Future at 0x7fcc483bddc0 state=pending>
# scheduled for PL: <Future at 0x7fcc483bda30 state=pending>
# scheduled for PT: <Future at 0x7fcc483bde50 state=pending>
# scheduled for PW: <Future at 0x7fcc483bd790 state=pending>
# scheduled for PY: <Future at 0x7fcc483ba250 state=pending>
# scheduled for QA: <Future at 0x7fcc483ba400 state=pending>
# scheduled for RO: <Future at 0x7fcc483ba5b0 state=pending>
# scheduled for RS: <Future at 0x7fcc483ba760 state=pending>
# scheduled for RU: <Future at 0x7fcc483ba910 state=pending>
# scheduled for RW: <Future at 0x7fcc483baac0 state=pending>
# scheduled for SA: <Future at 0x7fcc483bac70 state=pending>
# scheduled for SB: <Future at 0x7fcc483bae20 state=pending>
# scheduled for SC: <Future at 0x7fcc483baf40 state=pending>
# scheduled for SD: <Future at 0x7fcc483babe0 state=pending>
# scheduled for SE: <Future at 0x7fcc483ba700 state=pending>
# scheduled for SG: <Future at 0x7fcc483ba3d0 state=pending>
# scheduled for SI: <Future at 0x7fcc483bd8e0 state=pending>
# scheduled for SK: <Future at 0x7fcc483bdd00 state=pending>
# scheduled for SL: <Future at 0x7fcc48406550 state=pending>
# scheduled for SM: <Future at 0x7fcc48431f40 state=pending>
# scheduled for SN: <Future at 0x7fcc483d8af0 state=pending>
# scheduled for SO: <Future at 0x7fcc483d8cd0 state=pending>
# scheduled for SR: <Future at 0x7fcc483d8eb0 state=pending>
# scheduled for SS: <Future at 0x7fcc483dd0d0 state=pending>
# scheduled for ST: <Future at 0x7fcc483dd2b0 state=pending>
# scheduled for SV: <Future at 0x7fcc483dd490 state=pending>
# scheduled for SY: <Future at 0x7fcc483dd670 state=pending>
# scheduled for SZ: <Future at 0x7fcc483dd850 state=pending>
# scheduled for TD: <Future at 0x7fcc483dda30 state=pending>
# scheduled for TG: <Future at 0x7fcc483ddc10 state=pending>
# scheduled for TH: <Future at 0x7fcc483dddf0 state=pending>
# scheduled for TJ: <Future at 0x7fcc483ddfd0 state=pending>
# scheduled for TL: <Future at 0x7fcc483e11f0 state=pending>
# scheduled for TM: <Future at 0x7fcc483e13d0 state=pending>
# scheduled for TN: <Future at 0x7fcc483e15b0 state=pending>
# scheduled for TO: <Future at 0x7fcc483e1790 state=pending>
# scheduled for TR: <Future at 0x7fcc483e1970 state=pending>
# scheduled for TT: <Future at 0x7fcc483e1b50 state=pending>
# scheduled for TV: <Future at 0x7fcc483e1d30 state=pending>
# scheduled for TW: <Future at 0x7fcc483e1f10 state=pending>
# scheduled for TZ: <Future at 0x7fcc483e5130 state=pending>
# GRscheduled for UA: <Future at 0x7fcc483c07c0 state=pending>
# scheduled for UG: <Future at 0x7fcc4840ed00 state=pending>
# scheduled for US: <Future at 0x7fcc4840e220 state=pending>
# scheduled for UY: <Future at 0x7fcc4840e760 state=pending>
# scheduled for UZ: <Future at 0x7fcc49c5dd90 state=pending>
# scheduled for VA: <Future at 0x7fcc483e1eb0 state=pending>
# scheduled for VC: <Future at 0x7fcc483e1910 state=pending>
# scheduled for VE: <Future at 0x7fcc483e1520 state=pending>
# scheduled for VN: <Future at 0x7fcc483ddfa0 state=pending>
# scheduled for VU: <Future at 0x7fcc483ddb80 state=pending>
# scheduled for WS: <Future at 0x7fcc483dd640 state=pending>
# scheduled for YE: <Future at 0x7fcc483dd220 state=pending>
# scheduled for ZA: <Future at 0x7fcc483d8ca0 state=pending>
# scheduled for ZM: <Future at 0x7fcc48431e20 state=pending>
# scheduled for ZW: <Future at 0x7fcc483bd190 state=pending>
# <Future at 0x7fcc4840e7c0 state=finished returned str> result: 'CH'
# <Future at 0x7fcc49cbafa0 state=finished returned str> result: 'BO'
# <Future at 0x7fcc49c6df70 state=finished returned str> result: 'BW'
# <Future at 0x7fcc49cbaf40 state=finished returned str> result: 'BD'
# <Future at 0x7fcc48415730 state=finished returned str> result: 'DZ'
# <Future at 0x7fcc48415ee0 state=finished returned str> result: 'CI'
# <Future at 0x7fcc49ee7ee0 state=finished returned str> result: 'AG'
# <Future at 0x7fcc49c7b670 state=finished returned str> result: 'CO'
# <Future at 0x7fcc49cb8610 state=finished returned str> result: 'BB'
# <Future at 0x7fcc49c7edc0 state=finished returned str> result: 'BS'
# <Future at 0x7fcc49c5d7c0 state=finished returned str> result: 'BF'
# <Future at 0x7fcc49c7ed90 state=finished returned str> result: 'BR'
# <Future at 0x7fcc48415580 state=finished returned str> result: 'DM'
# <Future at 0x7fcc49c7bd60 state=finished returned str> result: 'FJ'
# <Future at 0x7fcc49c7b4f0 state=finished returned str> result: 'BY'
# <Future at 0x7fcc49ed8520 state=finished returned str> result: 'BH'
# <Future at 0x7fcc580f34f0 state=finished returned str> result: 'BA'
# <Future at 0x7fcc48406d00 state=finished returned str> result: 'CM'
# <Future at 0x7fcc49cb84f0 state=finished returned str> result: 'AM'
# <Future at 0x7fcc48415ca0 state=finished returned str> result: 'EG'
# <Future at 0x7fcc49c53c70 state=finished returned str> result: 'BI'
# <Future at 0x7fcc580b7460 state=finished returned str> result: 'AD'
# <Future at 0x7fcc49ed8460 state=finished returned str> result: 'CY'
# <Future at 0x7fcc48415c10 state=finished returned str> result: 'ER'
# <Future at 0x7fcc49c6dc10 state=finished returned str> result: 'CN'
# <Future at 0x7fcc49c7ec10 state=finished returned str> result: 'AU'
# <Future at 0x7fcc49c6d400 state=finished returned str> result: 'BZ'
# <Future at 0x7fcc49c7b3d0 state=finished returned str> result: 'ES'
# <Future at 0x7fcc49c7ebe0 state=finished returned str> result: 'AZ'
# <Future at 0x7fcc49c533d0 state=finished returned str> result: 'AT'
# <Future at 0x7fcc483fbaf0 state=finished returned str> result: 'CR'
# <Future at 0x7fcc49c7b310 state=finished returned str> result: 'FI'
# <Future at 0x7fcc49c5d310 state=finished returned str> result: 'DE'
# <Future at 0x7fcc48406310 state=finished returned str> result: 'CU'GN
# GT GQ HR<Future at 0x7fcc48406af0 state=finished returned str> result: 'DK'
#   GWHN  IE<Future at 0x7fcc49c7eaf0 state=finished returned str> result: 'AE'  GY HTHU
# <Future at 0x7fcc49ee7ac0 state=finished returned str> result: 'CG'
# <Future at 0x7fcc49ed8a90 state=finished returned str> result: 'AF'
# <Future at 0x7fcc48406a00 state=finished returned str> result: 'CF'
# <Future at 0x7fcc484061f0 state=finished returned str> result: 'CV'
# <Future at 0x7fcc49c5d1c0 state=finished returned str> result: 'DJ'
# <Future at 0x7fcc49c631c0 state=finished returned str> result: 'BJ'
# <Future at 0x7fcc484219a0 state=finished returned str> result: 'FR'
# <Future at 0x7fcc49c5d9a0 state=finished returned str> result: 'BE'
# <Future at 0x7fcc49eeb190 state=finished returned str> result: 'AR'
# <Future at 0x7fcc49c6d970 state=finished returned str> result: 'BN'
# <Future at 0x7fcc48421130 state=finished returned str> result: 'CL'
# <Future at 0x7fcc49c63130 state=finished returned str> result: 'CD'IQ  IN
# JO<Future at 0x7fcc49c5d8b0 state=finished returned str> result: 'CA'ID  ISIL
# <Future at 0x7fcc484150a0 state=finished returned str> result: 'EC'
# <Future at 0x7fcc580b7880 state=finished returned str> result: 'BT'
# <Future at 0x7fcc48415070 state=finished returned str> result: 'EE'
#    ITJP  KEIR<Future at 0x7fcc49c6d040 state=finished returned str> result: 'CZ'
#  JM<Future at 0x7fcc49eeb040 state=finished returned str> result: 'AL'
# <Future at 0x7fcc49ed8040 state=finished returned str> result: 'AO'
# <Future at 0x7fcc49c5d820 state=finished returned str> result: 'BG'
# <Future at 0x7fcc48421ee0 state=finished returned str> result: 'GB'KHKG
#  KI   KM<Future at 0x7fcc49c7b970 state=finished returned str> result: 'FM' LA KP
# <Future at 0x7fcc484215b0 state=finished returned str> result: 'GD'
# <Future at 0x7fcc48421c70 state=finished returned str> result: 'GE'
# <Future at 0x7fcc48421820 state=finished returned str> result: 'GH'
# <Future at 0x7fcc49c7b8e0 state=finished returned str> result: 'ET'
# <Future at 0x7fcc48431490 state=finished returned str> result: 'GQ'
# <Future at 0x7fcc48415cd0 state=finished returned str> result: 'HR'
# <Future at 0x7fcc48421430 state=finished returned str> result: 'GA'
# <Future at 0x7fcc484312b0 state=finished returned str> result: 'GN'
# <Future at 0x7fcc48431670 state=finished returned str> result: 'GR'
# <Future at 0x7fcc484310d0 state=finished returned str> result: 'GM'
# <Future at 0x7fcc48431850 state=finished returned str> result: 'GT'
# <Future at 0x7fcc48415040 state=finished returned str> result: 'HN'
# <Future at 0x7fcc4840e340 state=finished returned str> result: 'GY'LKLC
# KW  KR<Future at 0x7fcc48415d00 state=finished returned str> result: 'GW'KN
# LR  <Future at 0x7fcc49ee7f70 state=finished returned str> result: 'IE'LI
# <Future at 0x7fcc49c63dc0 state=finished returned str> result: 'HT'
# <Future at 0x7fcc484157f0 state=finished returned str> result: 'IL'
# <Future at 0x7fcc49c6d160 state=finished returned str> result: 'JO'
# <Future at 0x7fcc49ed85e0 state=finished returned str> result: 'IQ'
# <Future at 0x7fcc48415df0 state=finished returned str> result: 'IN'
# <Future at 0x7fcc483fbc10 state=finished returned str> result: 'JP'
# <Future at 0x7fcc49ee7910 state=finished returned str> result: 'ID'
# <Future at 0x7fcc4840e1f0 state=finished returned str> result: 'IT'
# <Future at 0x7fcc49c63550 state=finished returned str> result: 'HU'
# KZ  LB <Future at 0x7fcc483fbee0 state=finished returned str> result: 'KE'LU LS
#   <Future at 0x7fcc48406e80 state=finished returned str> result: 'KG'MCMG
# LT<Future at 0x7fcc4840ef70 state=finished returned str> result: 'IS'MA LV
# <Future at 0x7fcc48406f70 state=finished returned str> result: 'KH'
# <Future at 0x7fcc48406eb0 state=finished returned str> result: 'KI'
# <Future at 0x7fcc4840ee80 state=finished returned str> result: 'IR'
# <Future at 0x7fcc48435820 state=finished returned str> result: 'KM'LY
# <Future at 0x7fcc483bd7c0 state=finished returned str> result: 'LC'
# MNMH  <Future at 0x7fcc483bd400 state=finished returned str> result: 'LA'
# <Future at 0x7fcc49cbad90 state=finished returned str> result: 'JM'
# MLMMMRMK    MEMTMW <Future at 0x7fcc483bd040 state=finished returned str> result: 'KW'MXMZ MUMY   MD
# <Future at 0x7fcc48435e20 state=finished returned str> result: 'KR'NAMV
# <Future at 0x7fcc48435a60 state=finished returned str> result: 'KN'
# NE NG<Future at 0x7fcc48435c40 state=finished returned str> result: 'KP'
# NL  <Future at 0x7fcc483fb880 state=finished returned str> result: 'LK'
# NPNI <Future at 0x7fcc49c6d2e0 state=finished returned str> result: 'LU'
# <Future at 0x7fcc483fbb20 state=finished returned str> result: 'LR'
# <Future at 0x7fcc483bd220 state=finished returned str> result: 'KZ'
# <Future at 0x7fcc483bd5e0 state=finished returned str> result: 'LB'
# <Future at 0x7fcc483fb4f0 state=finished returned str> result: 'LS'
# <Future at 0x7fcc49c7edf0 state=finished returned str> result: 'MC'
# <Future at 0x7fcc484319a0 state=finished returned str> result: 'MG'
# <Future at 0x7fcc483bd970 state=finished returned str> result: 'LI'
# <Future at 0x7fcc49c63d90 state=finished returned str> result: 'MA'
# <Future at 0x7fcc483fbe80 state=finished returned str> result: 'LT'
# <Future at 0x7fcc483c63a0 state=finished returned str> result: 'MN'
# NO NR NZ<Future at 0x7fcc4840e280 state=finished returned str> result: 'LV'
# <Future at 0x7fcc483c0dc0 state=finished returned str> result: 'MK'
# <Future at 0x7fcc483c0be0 state=finished returned str> result: 'MH'
# <Future at 0x7fcc4840edf0 state=finished returned str> result: 'LY'
# <Future at 0x7fcc483c0fa0 state=finished returned str> result: 'ML'
# <Future at 0x7fcc483c6580 state=finished returned str> result: 'MR'
# <Future at 0x7fcc483c61c0 state=finished returned str> result: 'MM'
# <Future at 0x7fcc483ca2e0 state=finished returned str> result: 'MZ'
# <Future at 0x7fcc483c6760 state=finished returned str> result: 'MT'
# <Future at 0x7fcc483c6d00 state=finished returned str> result: 'MW'
# <Future at 0x7fcc49c53130 state=finished returned str> result: 'ME'
# <Future at 0x7fcc483ca100 state=finished returned str> result: 'MY'
# <Future at 0x7fcc48421790 state=finished returned str> result: 'MD'
# <Future at 0x7fcc483c6ee0 state=finished returned str> result: 'MX'
#   PE<Future at 0x7fcc49c7ec40 state=finished returned str> result: 'NL'OMPA
# <Future at 0x7fcc483c6b20 state=finished returned str> result: 'MV'
# <Future at 0x7fcc483caa60 state=finished returned str> result: 'NI'
# <Future at 0x7fcc483c6940 state=finished returned str> result: 'MU'
# <Future at 0x7fcc49ed8670 state=finished returned str> result: 'NR'
#   <Future at 0x7fcc483ca4c0 state=finished returned str> result: 'NA'
# <Future at 0x7fcc483ca6a0 state=finished returned str> result: 'NE'
# <Future at 0x7fcc483ca880 state=finished returned str> result: 'NG'
# PGPW PH QA PLPT  <Future at 0x7fcc483ba160 state=finished returned str> result: 'NO'
# PYRO RS <Future at 0x7fcc48431f10 state=finished returned str> result: 'PA'
# RW   <Future at 0x7fcc49eeb7c0 state=finished returned str> result: 'NZ'
# <Future at 0x7fcc49ed8b20 state=finished returned str> result: 'NP'
# SA <Future at 0x7fcc483ca670 state=finished returned str> result: 'OM'
# <Future at 0x7fcc48431070 state=finished returned str> result: 'PE'
# <Future at 0x7fcc483bdb20 state=finished returned str> result: 'PH'
# <Future at 0x7fcc483bd790 state=finished returned str> result: 'PW'
# <Future at 0x7fcc483ba760 state=finished returned str> result: 'RS'PK
# <Future at 0x7fcc483baac0 state=finished returned str> result: 'RW'
# SCRUSBSM  <Future at 0x7fcc483ba400 state=finished returned str> result: 'QA'
# <Future at 0x7fcc484063a0 state=finished returned str> result: 'PG'
# <Future at 0x7fcc483bde50 state=finished returned str> result: 'PT'SK  SG SI
# <Future at 0x7fcc483ba5b0 state=finished returned str> result: 'RO'
#  SL  SN <Future at 0x7fcc483ba250 state=finished returned str> result: 'PY' SO SE SR SD
# <Future at 0x7fcc483bac70 state=finished returned str> result: 'SA'
#  SV<Future at 0x7fcc483bdd00 state=finished returned str> result: 'SK'
#  SS<Future at 0x7fcc483bae20 state=finished returned str> result: 'SB'
# <Future at 0x7fcc483d8af0 state=finished returned str> result: 'SN'
# <Future at 0x7fcc483bda30 state=finished returned str> result: 'PL'
# <Future at 0x7fcc483bddc0 state=finished returned str> result: 'PK'
#  SY <Future at 0x7fcc48406550 state=finished returned str> result: 'SL'SZ
# TJ TDTH<Future at 0x7fcc483baf40 state=finished returned str> result: 'SC'
# <Future at 0x7fcc483bd8e0 state=finished returned str> result: 'SI'
# <Future at 0x7fcc483babe0 state=finished returned str> result: 'SD'
# <Future at 0x7fcc483ba910 state=finished returned str> result: 'RU'
# <Future at 0x7fcc48431f40 state=finished returned str> result: 'SM'
# <Future at 0x7fcc483ba3d0 state=finished returned str> result: 'SG'
# <Future at 0x7fcc483d8cd0 state=finished returned str> result: 'SO'
# <Future at 0x7fcc483dd490 state=finished returned str> result: 'SV'
# <Future at 0x7fcc483ba700 state=finished returned str> result: 'SE'
#   ST TL TN  TG <Future at 0x7fcc483d8eb0 state=finished returned str> result: 'SR'
# <Future at 0x7fcc483dd0d0 state=finished returned str> result: 'SS'
# <Future at 0x7fcc483dd670 state=finished returned str> result: 'SY'
# <Future at 0x7fcc483ddfd0 state=finished returned str> result: 'TJ'
# TT<Future at 0x7fcc483dd2b0 state=finished returned str> result: 'ST'
# UGTWTM   TRTV <Future at 0x7fcc483e15b0 state=finished returned str> result: 'TN'TO TZ
# <Future at 0x7fcc483dd850 state=finished returned str> result: 'SZ'
# <Future at 0x7fcc483dddf0 state=finished returned str> result: 'TH'
# <Future at 0x7fcc483dda30 state=finished returned str> result: 'TD'
#  <Future at 0x7fcc483e1b50 state=finished returned str> result: 'TT'
# <Future at 0x7fcc483e11f0 state=finished returned str> result: 'TL'UY
# UA  US <Future at 0x7fcc483ddc10 state=finished returned str> result: 'TG'
# <Future at 0x7fcc4840ed00 state=finished returned str> result: 'UG'
# UZVC<Future at 0x7fcc483e1d30 state=finished returned str> result: 'TV'
# <Future at 0x7fcc483e13d0 state=finished returned str> result: 'TM'
#  <Future at 0x7fcc483e1f10 state=finished returned str> result: 'TW' VE
# <Future at 0x7fcc483e5130 state=finished returned str> result: 'TZ'
#  VU<Future at 0x7fcc483e1970 state=finished returned str> result: 'TR'
# <Future at 0x7fcc4840e760 state=finished returned str> result: 'UY'
#  VA VN <Future at 0x7fcc483e1790 state=finished returned str> result: 'TO'
# <Future at 0x7fcc483c07c0 state=finished returned str> result: 'UA'
# <Future at 0x7fcc4840e220 state=finished returned str> result: 'US'
# <Future at 0x7fcc483e1910 state=finished returned str> result: 'VC'
# <Future at 0x7fcc49c5dd90 state=finished returned str> result: 'UZ'
# ZA<Future at 0x7fcc483e1520 state=finished returned str> result: 'VE'
#  <Future at 0x7fcc483ddb80 state=finished returned str> result: 'VU'
# <Future at 0x7fcc483e1eb0 state=finished returned str> result: 'VA'WS
#  <Future at 0x7fcc483ddfa0 state=finished returned str> result: 'VN'
# YE <Future at 0x7fcc483d8ca0 state=finished returned str> result: 'ZA'
# <Future at 0x7fcc483dd640 state=finished returned str> result: 'WS'
# <Future at 0x7fcc483dd220 state=finished returned str> result: 'YE'ZM
#  ZW <Future at 0x7fcc48431e20 state=finished returned str> result: 'ZM'
# <Future at 0x7fcc483bd190 state=finished returned str> result: 'ZW'
#
# donwloaded 194 flags in 0.8898s

# %%
from concurrent import futures
from timeit import timeit

MAX_WORKERS = 20


def download_one(cc):
    image = get_flag(cc)
    show(cc)
    save_flag(image, cc.lower() + '.gif')
    return cc


def download_many(cc_list):
    with futures.ProcessPoolExecutor() as executor:
        results = executor.map(download_one, sorted(cc_list))

    return len(list(results))


main(download_many)
# Out:
# AD AEAF AG   ALAM AR AT  AOAUAZ  BB BA BDBF BE BG  BH BI BJ BN BO BRBS  BT BW BY BZ CA CD CF CG CH CI CLCM  CN CO CRCU  CV CY CZ DE DJDK  DM DZ EC EE EG ER ESET  FI FJ FM FR GA GB GD GE GH GM GN GQ GR GT GW GY HN HR HT HU ID IE IL IN IR IQ IS ITJM  JO JP KE KGKH  KI KN KM KR KP KW KZ LA LB LC LI LK LR LS LT LU LV LY MA MC MD ME MG MH MK ML MM MN MR MT MU MV MW MX MY MZ NA NENG  NINL  NO NP NR NZ OM PA PG PE PH PK PL PT PW PY QA RO RS RU RW SA SB SC SD SE SG SI SK SL SM SN SO SR SS ST SV SY SZ TDTG  TH TJ TL TM TN TO TT TR TV TW TZ UA UG US UZ UY VA VC VE VN VU WS YE ZA ZM ZW
# donwloaded 194 flags in 1.5326s

# %%
from time import sleep, strftime
from concurrent import futures


def display(*args):
    print(strftime('[%H:%M:%S]'), end=' ')
    print(*args)


def loiter(n):
    msg = '{}loiter({}): doing nothing for {}s...'
    display(msg.format('\t'*n, n, n))
    sleep(n)
    msg = '{}loiter({}): done'
    display(msg.format('\t'*n, n))
    return n * 10


display('script starting')
executor = futures.ThreadPoolExecutor(max_workers=3)
results = executor.map(loiter, range(5))
display('results:', results)
display('waiting for individual results:')
for i, result in enumerate(results):
    display('result {}: {}'.format(i, result))
# Out:
# [05:29:07] script starting
# [05:29:07] loiter(0): doing nothing for 0s...
# [05:29:07] loiter(0): done
# [05:29:07] 	loiter(1): doing nothing for 1s...
# [05:29:07][05:29:07] 			loiter(3): doing nothing for 3s...
#  		loiter(2): doing nothing for 2s...
# [05:29:07] results: <generator object Executor.map.<locals>.result_iterator at 0x7fcc49cb5ac0>
# [05:29:07] waiting for individual results:
# [05:29:07] result 0: 0
# [05:29:08] 	loiter(1): done
# [05:29:08] 				loiter(4): doing nothing for 4s...
# [05:29:08] result 1: 10
# [05:29:09] 		loiter(2): done
# [05:29:09] result 2: 20
# [05:29:10] 			loiter(3): done
# [05:29:10] result 3: 30
# [05:29:12] 				loiter(4): done
# [05:29:12] result 4: 40
